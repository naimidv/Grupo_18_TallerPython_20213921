# %% [markdown]
# # Tarea 1

# %% [markdown]
# I. Utilizando un “if else” cree una estructura que evalúe “x” tal que:

# %%
x=6
if x%2==0:
    if x%3==0:
        print("Es múltiplo de 2 y 3")
    else:
        print("Es múltiplo de 2")
elif x%3==0:
    print("Es múltiplo de 3")
else:
    print("Otro caso")
# Out:
# Es múltiplo de 2 y 3

# %% [markdown]
# II.  Utilizando un “for loop” y el condicional “if else” para un rango del 1 al 100, evalúe “x”
# tal que:

# %%
nums=range(1,101)
for x in nums:
    if x%3==0:
        if x%5==0:
            print("FizzBuzz")
        else:
            print("Fizz")
    elif x%5==0:
        print("Buzz")
    else:
        print(x)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz

# %% [markdown]
# III. Crea una función 𝒄𝒂𝒍𝒄𝒖𝒍𝒂𝒓_𝒅𝒆𝒔𝒄𝒖𝒆𝒏𝒕𝒐() que permita calcular el descuento aplicado a un
# producto.

# %%
def calcular_descuento(tot):
    if tot>=1000:
        desc=0.2
    elif tot>=500 and tot<1000:
        desc=0.1
    else:
        desc=0
    return tot-(tot*desc)

# %%
totales=[1200, 750, 300]
for tot in totales:
    print(calcular_descuento(tot))
# Out:
# 960.0
# 675.0
# 300

# %%
def clasificar_edad(edad):
    if edad < 12:
        return "Niño"
    elif 12 <= edad <= 17:
        return "Adolescente"
    elif 18 <= edad <= 24:
        return "Joven"
    elif 25 <= edad <= 64:
        return "Adulto"
    elif edad >= 65:
        return "Adulto Mayor"

# %%
edades = [10, 19, 25, 70]
for edad in edades:
    print(clasificar_edad(edad))
# Out:
# Niño
# Joven
# Adulto
# Adulto Mayor

# %% [markdown]
# V. Sea la fórmula del CRAEST PUCP

# %%
def calcular_craest(media_personal, media_curso, desviacion_curso):
    craest = ((media_personal - media_curso) * 10) / desviacion_curso + 50
    return craest

# %%
#prueba
calcular_craest(15.64,12.1,2.2)
# Out:
# 66.0909090909091
