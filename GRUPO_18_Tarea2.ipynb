# %%
# !pip install pandas
import pandas as pd  #libreria pandas (pd)

# %% [markdown]
# 1. Copia el siguiente diccionario en una cédula de Colab. A partir de él, crea un dataframe
# llamado 𝒏𝒇 o utilizando Pandas.

# %%
data_ciudades = {'Ciudad': ['Lima', 'Arequipa', 'Trujillo', 'Cusco', 'Chiclayo', 'Piura', 'Iquitos', 'Huancayo', 'Tacna', 'Pucallpa'], 'Habitantes':[1047996, 100169, 92331, 428450, 305717, 484475, 441649, 385098, 294395, 283734], 'Area_km2':[2672.28, 1545.77, 1487.7, 116.5, 279.89, 6217.26, 368.9, 109.19, 59.4, 483.44], 'Altitud_m':[154, 2325, 34, 3399, 29, 29, 106, 3271, 562, 156], 'Densidad_poblacion_por_km2':[3924, 64.8, 62.1, 3673, 1091.6, 77.9, 1196, 3528.6, 4966, 587.2]}

nf = pd.DataFrame(data_ciudades)
nf
# Out:
#      Ciudad  Habitantes  Area_km2  Altitud_m  Densidad_poblacion_por_km2
# 0      Lima     1047996   2672.28        154                      3924.0
# 1  Arequipa      100169   1545.77       2325                        64.8
# 2  Trujillo       92331   1487.70         34                        62.1
# 3     Cusco      428450    116.50       3399                      3673.0
# 4  Chiclayo      305717    279.89         29                      1091.6
# 5     Piura      484475   6217.26         29                        77.9
# 6   Iquitos      441649    368.90        106                      1196.0
# 7  Huancayo      385098    109.19       3271                      3528.6
# 8     Tacna      294395     59.40        562                      4966.0
# 9  Pucallpa      283734    483.44        156                       587.2

# %% [markdown]
# 2. Realiza el mismo procedimiento con el siguiente diccionario. A partir de él, crea un
# dataframe llamado 𝒏𝒐𝒎𝒃𝒓𝒆𝒔.

# %%
data_ciudades_2= {'Ciudad':['Lima', 'Arequipa', 'Trujillo', 'Cusco', 'Chiclayo', 'Piura', 'Iquitos', 'Huancayo', 'Tacna', 'Pucallpa'], 'Gentilicio': ['Limense', 'Arequipeño', 'Trujillano', 'Cusqueño', 'Chiclayano', 'Piurano', 'Iquiteño', 'Huancaino', 'Tacneño', 'Pucallpino'], 'Provincia': ['Lima', 'Arequipa', 'Trujillo', 'Cusco', 'Chiclayo', 'Piura', 'Maynas', 'Huancayo', 'Tacna', 'Coronel Portillo'], 'Region':['Lima', 'Arequipa', 'La Libertad', 'Cusco', 'Lambayeque', 'Piura', 'Loreto', 'Junin', 'Tacna', 'Ucayali'] }
nombres = pd.DataFrame(data_ciudades_2)
nombres
# Out:
#      Ciudad  Gentilicio         Provincia       Region
# 0      Lima     Limense              Lima         Lima
# 1  Arequipa  Arequipeño          Arequipa     Arequipa
# 2  Trujillo  Trujillano          Trujillo  La Libertad
# 3     Cusco    Cusqueño             Cusco        Cusco
# 4  Chiclayo  Chiclayano          Chiclayo   Lambayeque
# 5     Piura     Piurano             Piura        Piura
# 6   Iquitos    Iquiteño            Maynas       Loreto
# 7  Huancayo   Huancaino          Huancayo        Junin
# 8     Tacna     Tacneño             Tacna        Tacna
# 9  Pucallpa  Pucallpino  Coronel Portillo      Ucayali

# %% [markdown]
# 3. Con ambos dataframes, realiza un inner join. Guarda el resultado en un nuevo dataframe
# llamado 𝒄𝒖𝒂𝒅𝒓𝒐_𝟏

# %%
cuadro_1 = pd.merge(nf, nombres, on='Ciudad', how='inner')
cuadro_1
# Out:
#      Ciudad  Habitantes  Area_km2  Altitud_m  Densidad_poblacion_por_km2  \
# 0      Lima     1047996   2672.28        154                      3924.0
# 1  Arequipa      100169   1545.77       2325                        64.8
# 2  Trujillo       92331   1487.70         34                        62.1
# 3     Cusco      428450    116.50       3399                      3673.0
# 4  Chiclayo      305717    279.89         29                      1091.6
# 5     Piura      484475   6217.26         29                        77.9
# 6   Iquitos      441649    368.90        106                      1196.0
# 7  Huancayo      385098    109.19       3271                      3528.6
# 8     Tacna      294395     59.40        562                      4966.0
# 9  Pucallpa      283734    483.44        156                       587.2
#
#    Gentilicio         Provincia       Region
# 0     Limense              Lima         Lima
# 1  Arequipeño          Arequipa     Arequipa
# ...

# %% [markdown]
# 4. Resume las estadísticas descriptivas del dataframe y responde ¿Cuál es la mínima
# densidad poblacional? ¿A cuál ciudad corresponde? ¿Y la máxima?

# %%
cuadro_1.describe()
# Out:
#          Habitantes    Area_km2    Altitud_m  Densidad_poblacion_por_km2  \
# count  1.000000e+01    10.00000    10.000000                   10.000000
# mean   3.864014e+05  1334.03300  1006.500000                 1917.120000
# std    2.679283e+05  1917.13852  1410.508754                 1892.333136
# min    9.233100e+04    59.40000    29.000000                   62.100000
# 25%    2.863992e+05   157.34750    52.000000                  205.225000
# 50%    3.454075e+05   426.17000   155.000000                 1143.800000
# 75%    4.383492e+05  1531.25250  1884.250000                 3636.900000
# max    1.047996e+06  6217.26000  3399.000000                 4966.000000
#
#        ciudad
# count     1.0
# mean     62.1
# std       NaN
# min      62.1
# 25%      62.1
# 50%      62.1
# 75%      62.1
# max      62.1

# %%
densidad_minima = cuadro_1['Densidad_poblacion_por_km2'].min()
ciudad_minima = cuadro_1.loc[cuadro_1['Densidad_poblacion_por_km2']==densidad_minima, 'Ciudad'].values[0]

densidad_maxima = cuadro_1['Densidad_poblacion_por_km2'].max()
ciudad_maxima = cuadro_1.loc[cuadro_1['Densidad_poblacion_por_km2']==densidad_maxima, 'Ciudad'].values[0]

print(f"La mínima densidad poblacional es {densidad_minima} y corresponde a la ciudad de {ciudad_minima}.")
print(f"La máxima densidad poblacional es {densidad_maxima} y corresponde a la ciudad de {ciudad_maxima}.")
# Out:
# La mínima densidad poblacional es 62.1 y corresponde a la ciudad de Trujillo.
# La máxima densidad poblacional es 4966.0 y corresponde a la ciudad de Tacna.

# %% [markdown]
# 5. Realizar un gráfico de barras donde se vea la cantidad de habitantes en cada ciudad

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.bar(x = cuadro_1["Ciudad"], height= cuadro_1["Habitantes"], color="steelblue")
ax.set_xlabel('Ciudad')
ax.set_ylabel('Habitantes')
ax.set_title('Número de Habitantes por Ciudad en Perú')
ax.tick_params(axis="x", rotation=45)
plt.show()

# %% [markdown]
# 6. Realizar un gráfico de dispersión entre la altura y el número de habitantes en las
# ciudades del dataframe

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.scatter(cuadro_1['Altitud_m'], cuadro_1['Habitantes'], color='green')
ax.set_title('Relación entre Altitud y Número de Habitantes de las Ciudades en Perú')
ax.set_xlabel('Altitud (m)')
ax.set_ylabel('Habitantes')

ax.grid(True)

plt.show()
